# %%
# !pip install laspy
# !pip install open3d
# !python3 -m pip install "laspy[lazrs,laszip]"
# !pip install cloth-simulation-filter
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: laspy in /Users/nmhillesund/Library/Python/3.9/lib/python/site-packages (2.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from laspy) (1.25.2)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: /usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: open3d in /usr/local/lib/python3.9/site-packages (0.17.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.9/site-packages (from open3d) (1.25.2)
# Requirement already satisfied: dash>=2.6.0 in /usr/local/lib/python3.9/site-packages (from open3d) (2.14.1)
# Requirement already satisfied: werkzeug>=2.2.3 in /usr/local/lib/python3.9/site-packages (from open3d) (3.0.1)
# Requirement already satisfied: nbformat==5.7.0 in /usr/local/lib/python3.9/site-packages (from open3d) (5.7.0)
# Requirement already satisfied: configargparse in /usr/local/lib/python3.9/site-packages (from open3d) (1.7)
# Requirement already satisfied: addict in /usr/local/lib/python3.9/site-packages (from open3d) (2.4.0)
# Requirement already satisfied: pillow>=9.3.0 in /usr/local/lib/python3.9/site-packages (from open3d) (10.0.0)
# Requirement already satisfied: matplotlib>=3 in /usr/local/lib/python3.9/site-packages (from open3d) (3.8.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.9/site-packages (from open3d) (2.1.0)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.9/site-packages (from open3d) (6.0.1)
# Requirement already satisfied: scikit-learn>=0.21 in /usr/local/lib/python3.9/site-packages (from open3d) (1.3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from open3d) (4.66.1)
# Requirement already satisfied: pyquaternion in /usr/local/lib/python3.9/site-packages (from open3d) (0.9.9)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/site-packages (from nbformat==5.7.0->open3d) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/site-packages (from nbformat==5.7.0->open3d) (4.4.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/site-packages (from nbformat==5.7.0->open3d) (4.9.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.9/site-packages (from nbformat==5.7.0->open3d) (5.1.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (3.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (5.18.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/nmhillesund/Library/Python/3.9/lib/python/site-packages (from dash>=2.6.0->open3d) (4.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (2.27.1)
# Requirement already satisfied: retrying in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (1.3.4)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (1.8.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (1.5.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (60.5.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/site-packages (from dash>=2.6.0->open3d) (6.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3->open3d) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3->open3d) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3->open3d) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3->open3d) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3->open3d) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3->open3d) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3->open3d) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3->open3d) (6.0.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas>=1.0->open3d) (2021.3)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.9/site-packages (from pandas>=1.0->open3d) (2023.3)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn>=0.21->open3d) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/site-packages (from scikit-learn>=0.21->open3d) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn>=0.21->open3d) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/site-packages (from werkzeug>=2.2.3->open3d) (2.1.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (1.6.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/site-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.16.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat==5.7.0->open3d) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat==5.7.0->open3d) (0.18.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (8.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3->open3d) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->dash>=2.6.0->open3d) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->dash>=2.6.0->open3d) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/nmhillesund/Library/Python/3.9/lib/python/site-packages (from requests->dash>=2.6.0->open3d) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->dash>=2.6.0->open3d) (3.3)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: /usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: laspy[laszip,lazrs] in /Users/nmhillesund/Library/Python/3.9/lib/python/site-packages (2.3.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from laspy[laszip,lazrs]) (1.20.2)
# Requirement already satisfied: lazrs<0.5.0,>=0.4.3 in /Users/nmhillesund/Library/Python/3.9/lib/python/site-packages (from laspy[laszip,lazrs]) (0.4.5)
# Requirement already satisfied: laszip<0.2.0,>=0.1.0 in /Users/nmhillesund/Library/Python/3.9/lib/python/site-packages (from laspy[laszip,lazrs]) (0.1.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: cloth-simulation-filter in /usr/local/lib/python3.9/site-packages (1.1.4)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: /usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip

# %%
# Imports

import laspy 
import open3d as o3d
import numpy as np
import os
import matplotlib.pyplot as plt
import CSF

# %%
# Read the data
las_path = "data.las"
las_data = laspy.read(las_path)

# Extract the points
points = np.vstack((las_data.x, las_data.y, las_data.z)).transpose()

# Create an empty Open3D point cloud object
point_cloud = o3d.geometry.PointCloud()

# Insert the filtered points into the point cloud object
point_cloud.points = o3d.utility.Vector3dVector(points)

#o3d.visualization.draw_geometries([point_cloud])

num_org = len(point_cloud.points)

# %%
csf = CSF.CSF()

# prameter settings
csf.params.bSloopSmooth = False
csf.params.cloth_resolution = 0.5
# more details about parameter: http://ramm.bnu.edu.cn/projects/CSF/download/

csf.setPointCloud(points)
ground = CSF.VecInt()  # a list to indicate the index of ground points after calculation
non_ground = CSF.VecInt() # a list to indicate the index of non-ground points after calculation
csf.do_filtering(ground, non_ground) # do actual filtering.
# Out:
# [0] Configuring terrain...
# [0] Configuring cloth...
# [0]  - width: 272 height: 362
# [0] Rasterizing...
# [0] Simulating...

# %%
ground_removed = points[np.array(non_ground)]

# Create an empty Open3D point cloud object
point_cloud = o3d.geometry.PointCloud()

# Insert the filtered points into the point cloud object
point_cloud.points = o3d.utility.Vector3dVector(ground_removed)

o3d.visualization.draw_geometries([point_cloud])
# Check the reducion of points after downsampling
num_ng = len(point_cloud.points)
reduction = 100-(num_ng/num_org * 100)
print(f'From {num_org} to {num_ng} points. Equals a {round(reduction,2)} % reduction')
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# From 22176864 to 18879782 points. Equals a 14.87 % reduction

# %%
# Downsampling

point_cloud_ds = point_cloud.voxel_down_sample(voxel_size=0.25)
o3d.visualization.draw_geometries([point_cloud_ds])
# Check the reducion of points after downsampling
num_ds = len(point_cloud_ds.points)
reduction = 100-(num_ds/num_ng * 100)
print(f'From {num_ng} to {num_ds} points. Equals a {round(reduction,2)} % reduction')
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# From 18879782 to 833067 points. Equals a 95.59 % reduction

# %%
# Terrain filtering using statistical outlier removal (SOR)
point_cloud_so, ind = point_cloud_ds.remove_statistical_outlier(nb_neighbors=20, std_ratio=0.2)
#filtered_pcd = point_cloud.select_by_index(ind)
o3d.visualization.draw_geometries([point_cloud_so])
# Check the reducion of points after downsampling
num_so = len(point_cloud_so.points)
reduction = 100-(num_so/num_ds * 100)
print(f'From {num_ds} to {num_so} points. Equals a {round(reduction,2)} % reduction')
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# From 833067 to 660724 points. Equals a 20.69 % reduction

# %%
points = np.asarray(point_cloud_so.points)

# define slice levels
z_levels = [0.1, 0.4, 0.7]  

# Create an empty point cloud for the slices
slices_pcd = o3d.geometry.PointCloud()

for z in z_levels:
    # Define a threshold for the slice thickness
    z_threshold = 0.05
    # Select points that fall within the Z level +/- threshold
    slice_mask = (points[:, 2] > (z - z_threshold)) & (points[:, 2] < (z + z_threshold))
    slice_points = points[slice_mask, :3]  # Keep XYZ coordinates for the slice
    
    # Append slice points to the slices_pcd point cloud
    if len(slice_points) > 0:
        slice_pcd = o3d.geometry.PointCloud()
        slice_pcd.points = o3d.utility.Vector3dVector(slice_points)
        slices_pcd += slice_pcd  # Merge the slice into the main slices point cloud

# Visualize all slices together
o3d.visualization.draw_geometries([slices_pcd])
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display

# %%
# Load your point cloud data
pcd = o3d.io.read_point_cloud("point_cloud.pcd")

# Define the heights for the three slices
slice_heights = [0.1, 0.4, 0.7]  # Adjust the heights as needed

# Initialize a list to store the slices
slices = []

# Slice the point cloud into three parts
for i in range(2):
    min_slice_height = slice_heights[i]
    max_slice_height = slice_heights[i + 1]
    
    # Extract points within the height range for the current slice
    slice_indices = np.where(
        (min_slice_height <= np.asarray(pcd.points)[:, 2]) &
        (np.asarray(pcd.points)[:, 2] <= max_slice_height)
    )
    slice_pcd = pcd.select_by_index(slice_indices[0])
    
    # Add the slice to the list
    slices.append(slice_pcd)
print(slices)
# Create an empty point cloud for the slices
#slices_pcd = o3d.geometry.PointCloud()
#slice_pcd.points = o3d.utility.Vector3dVector(np.asarray(slices))
#o3d.visualization.draw_geometries([slices_pcd])
# Out:
# [Open3D WARNING] Read PCD failed: unable to open file: point_cloud.pcd
# [PointCloud with 0 points., PointCloud with 0 points.]

# %%
# Find clusters
with o3d.utility.VerbosityContextManager(
        o3d.utility.VerbosityLevel.Debug) as cm:
    labels = np.array(
        slices_pcd.cluster_dbscan(eps=0.4, min_points=4, print_progress=True))

max_label = labels.max()
print(f"point cloud has {max_label + 1} clusters")
colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
colors[labels < 0] = 0
slices_pcd.colors = o3d.utility.Vector3dVector(colors[:, :3])
o3d.visualization.draw_geometries([slices_pcd])
# Out:
# [Open3D DEBUG] Precompute neighbors.
# Precompute neighbors.[========================>
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 409
# Precompute neighbors.[========================================] 100%
# Clustering[==============================>         ] 75%
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display

# %%
# Extract individual point clouds to remove unwanted clusters

ind_point_clouds = []
for cluster_label in range(max_label + 1):
    
    cluster_indices = np.where(labels == cluster_label)[0]
    
    cluster_points = slices_pcd.select_by_index(cluster_indices)

    # Remove clusters under a certain size
    cluster_size = len(cluster_points.points)
    if(10 < cluster_size):
        ind_point_clouds.append(cluster_points)
        
print(len(ind_point_clouds))
# Out:
# 62

# %%
# Create an empty point cloud for the complete point cloud
complete_point_cloud = o3d.geometry.PointCloud()

# Iterate over each individual point cloud and add it to the complete point cloud
for point_cloud in ind_point_clouds:
    complete_point_cloud += point_cloud

# Visualize the complete point cloud
o3d.visualization.draw_geometries([complete_point_cloud])

# Return the number of points in the complete point cloud
len(np.asarray(complete_point_cloud.points))
# Out:
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# 1801

# %%
# Initialize an empty list to store 2D points of all clusters
clusters_2d_points = []

# Iterate over each individual point cloud cluster
for pcd in ind_point_clouds:
    # Convert to numpy array
    points = np.asarray(pcd.points)
    # Flatten the Z-coordinate and keep as separate clusters
    points_2d = points[:, :2]
    clusters_2d_points.append(points_2d)

# Now `clusters_2d_points` is a list of 2D arrays where each array corresponds to a cluster

len(clusters_2d_points)
# Out:
# 62

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

def fit_circle_ransac(points, iterations=1000, inlier_thresh=0.025, min_inliers=20, min_inlier_percentage=0.7):
    best_circle = None
    best_inlier_count = 0
    best_inlier_mask = None
    best_inlier_mse = float('inf')
    num_points = len(points)
    
    # Helper function to calculate the distance from points to the circle
    def point_to_circle_dist(points, circle):
        center_x, center_y, radius = circle
        return np.abs(np.sqrt((points[:, 0] - center_x)**2 + (points[:, 1] - center_y)**2) - radius)

    for _ in range(iterations):
        # Randomly select 3 points to define a circle
        sample_points = points[np.random.choice(points.shape[0], 3, replace=False), :]
        circle = fit_circle_least_squares(sample_points)
        
        # Calculate distances from all points to the circle
        distances = point_to_circle_dist(points, circle)
        
        # Determine inliers based on the distance threshold
        inlier_mask = distances < inlier_thresh
        inlier_count = np.sum(inlier_mask)
        
        if inlier_count > 0:
            # Calculate mean squared error for inliers
            inlier_mse = mean_squared_error(np.zeros(np.sum(inlier_mask)), distances[inlier_mask])

            inlier_percentage = inlier_count / num_points
            # Update best circle if this one has more inliers and a lower MSE
            if inlier_count > best_inlier_count and inlier_count >= min_inliers and inlier_mse < best_inlier_mse and inlier_percentage > min_inlier_percentage:
                best_circle = circle
                best_inlier_count = inlier_count
                best_inlier_mask = inlier_mask
                best_inlier_mse = inlier_mse
            
    return best_circle, best_inlier_mask

# Helper function for least squares circle fit
def fit_circle_least_squares(points):
    # Your least squares circle fitting logic
    # For now, let's just use the mean of the points as the center and the average distance to the center as the radius
    center_x = np.mean(points[:, 0])
    center_y = np.mean(points[:, 1])
    radius = np.mean(np.sqrt((points[:, 0] - center_x)**2 + (points[:, 1] - center_y)**2))
    return (center_x, center_y, radius)

def plot_result(points_2d, inlier_mask, circle_parameters):
    print("Best fit circle center: ({}, {}) with radius {}".format(*circle_parameters))
    # Begin plotting
    fig, ax = plt.subplots()
    ax.scatter(points_2d[:, 0], points_2d[:, 1], color='blue', label='Outliers')
    ax.scatter(points_2d[inlier_mask, 0], points_2d[inlier_mask, 1], color='red', label='inliers')

    [center_x, center_y, radius] = circle_parameters
    circle_plot = plt.Circle((center_x, center_y), radius, color='red', fill=False, linewidth=2)
    ax.add_artist(circle_plot)

# %%
result = []
for cluster in clusters_2d_points:
    print(cluster)
    best_circle, inliers = fit_circle_ransac(cluster)
    if(best_circle):
        print(best_circle)
        plot_result(cluster, inliers, best_circle)
        result.append(best_circle)
# Out:
# [[-7.34895    21.9726    ]
#  [-7.0862     21.971     ]
#  [-6.93505    22.298325  ]
#  [-6.879675   22.14125   ]
#  [-7.13582    21.61982   ]
#  [-6.93047879 21.65754848]
#  [-7.130225   22.067275  ]
#  [-7.14724694 21.38663265]
#  [-6.88950488 21.88801707]
#  [-8.19113333 19.99793333]
#  [-7.22716897 21.10347241]
#  [-7.252328   20.581192  ]
#  [-7.261425   20.92294167]
#  [-8.808175   19.96203333]
#  [-8.61518605 20.1023938 ]
#  [-7.59265    21.6088375 ]
#  [-7.4251     20.46366533]
#  [-8.357425   20.40676667]
#  [-8.709825   20.34597857]
#  [-8.36868964 20.13477689]
#  [-7.66358456 20.39964191]
#  [-8.15746517 20.15346448]
#  [-8.71984444 20.57555556]
#  [-7.58115789 21.37144737]
#  [-7.58612143 21.19445714]
#  [-7.40734903 20.6428071 ]
#  [56.5514     13.5109    ]
#  [55.9215     12.5766    ]
#  [56.6267     12.494     ]
#  [56.3429     12.4984    ]
#  [56.1814     13.8068    ]
#  [56.0625     12.62836667]
#  [56.5017     13.571     ]
#  [56.5331     13.79115   ]
#  [56.04208333 12.45335   ]
#  [56.6346     12.7369    ]
#  [55.90665    13.8429    ]
#  [56.2352     13.0602    ]
#  [56.04884    13.91053   ]
#  [56.12684375 14.0991    ]
#  [56.56238333 12.84596667]
#  [56.86975    12.8559    ]
#  [56.08430625 13.90669375]]
# [[ 37.91075747 -36.38645057]
#  [ 37.87937778 -36.52264444]
#  [ 38.07935733 -36.333524  ]
#  [ 38.16898649 -36.1856    ]
#  [ 38.0171     -35.744     ]
#  [ 37.73145    -36.9163    ]
#  [ 37.7385     -36.6244    ]
#  [ 37.9681     -35.4725    ]
#  [ 37.50112857 -37.05147143]
#  [ 38.09070833 -36.1845    ]
#  [ 37.8622     -35.78315556]
#  [ 37.85616916 -36.14213458]
#  [ 38.0305     -35.4797    ]
#  [ 38.05109286 -35.58045714]
#  [ 37.85698667 -36.27402667]
#  [ 37.44       -36.72996   ]
#  [ 37.60309029 -36.66125825]
#  [ 37.905125   -35.63141111]
#  [ 37.5693     -36.4323    ]
#  [ 36.88842857 -37.20985714]
#  [ 37.81807719 -36.34550877]
#  [ 38.29563333 -36.27301667]
#  [ 37.576065   -36.906755  ]
#  [ 37.89403684 -36.19935263]
#  [ 37.17634    -36.92263   ]
#  [ 36.86083774 -37.36869245]
#  [ 37.1737975  -37.1588075 ]
#  [ 37.662975   -36.22545   ]
#  [ 37.64668936 -36.34211915]
#  [ 37.59571373 -37.12858627]
#  [ 36.8737     -37.5919    ]
#  [ 37.67144    -36.63472   ]
#  [ 37.82575455 -36.83742727]
#  [ 37.18215833 -36.9312    ]]
# [[44.535225   46.108175  ]
#  [42.85668    46.88016   ]
#  [43.8048     46.8408    ]
#  [44.7074     46.4586    ]
#  [41.7485     46.6774    ]
#  [44.82653333 46.4616    ]
#  [43.921475   46.63925   ]
#  [42.78038333 46.67356667]
#  [42.12424286 46.378     ]
#  [44.29335    46.421575  ]
#  [43.16845    46.72905   ]
#  [43.1595     47.13352   ]
#  [43.0731     46.87146667]
#  [44.3029     46.6258    ]
#  [42.29662941 46.38168235]
#  [41.86092647 46.05215882]
#  [41.8459     46.85064   ]
#  [42.56865185 46.35724815]
#  [42.5448     46.61873   ]
#  [43.5292     46.703525  ]
#  [43.2675     47.0279    ]
#  [43.04071667 47.3788    ]
#  [41.94193333 46.33786667]
#  [44.5108     46.5267    ]
#  [43.32257273 46.86359091]
#  [44.329675   46.5977375 ]
#  [45.0205     46.3267    ]
#  [43.6644     46.7997    ]
#  [41.61627143 46.37241429]
#  [41.8656375  46.4238875 ]
#  [43.4946     46.5089    ]
#  [43.83275    46.7342    ]
#  [41.99935    45.94445   ]
#  [41.91568333 45.95226667]
#  [41.8243     46.59516667]
#  [43.8916     46.5198    ]
#  [43.5777     46.8162    ]
#  [43.26585    46.91645   ]
#  [43.2106     46.6929    ]
#  [41.647      46.6651    ]
#  [41.96       46.8829    ]
#  [43.6028     46.9525    ]
#  [41.74565    46.41795   ]
#  [41.64005    46.3908875 ]
#  [41.4197     46.681     ]]
# [[ 12.56726667 -69.1153    ]
#  [ 13.019775   -69.509975  ]
#  [ 12.32514286 -69.37606429]
#  [ 12.40628667 -69.60746   ]
#  [ 12.75984444 -69.63295556]
#  [ 12.12025556 -69.295     ]
#  [ 12.3236     -69.1937    ]
#  [ 13.07694286 -69.394     ]
#  [ 12.61721429 -69.37791429]
#  [ 12.8296     -69.1818    ]
#  [ 13.07243333 -69.05913333]
#  [ 12.1877     -68.9647    ]
#  [ 12.3869     -69.08701   ]
#  [ 12.6522     -68.9402    ]
#  [ 12.17606667 -69.09406667]
#  [ 12.5407     -68.7364    ]
#  [ 12.2862     -69.2451    ]
#  [ 12.37455    -69.5068    ]
#  [ 12.532525   -69.2434    ]
#  [ 12.4007     -69.0723    ]
#  [ 12.05316667 -69.36616667]]
# [[ 55.25704444 -41.14688889]
#  [ 55.2268     -41.2661    ]
#  [ 55.1147     -40.8709    ]
#  [ 54.54701111 -41.10152222]
#  [ 54.87318462 -41.12612308]
#  [ 55.0764     -41.1282    ]
#  [ 54.42547273 -41.08340909]
#  [ 54.87823    -41.603425  ]
#  [ 55.039025   -41.290475  ]
#  [ 54.888764   -41.362576  ]
#  [ 54.66695    -41.51565   ]
#  [ 54.37696667 -41.60553333]
#  [ 54.158      -41.1203    ]
#  [ 54.1567375  -41.8347625 ]
#  [ 54.40966364 -41.09923636]
#  [ 54.54271    -41.12134   ]
#  [ 54.40146667 -41.5852    ]]
# [[-6.41094222 26.60333778]
#  [-6.25236571 26.21802286]
#  [-6.64085    26.857725  ]
#  [-6.95322    25.48932   ]
#  [-6.1321     26.40754   ]
#  [-6.37896282 26.15304359]
#  [-6.1599     26.69646923]
#  [-6.64718409 26.44499318]
#  [-6.62480513 26.04600256]
#  [-6.70855909 25.65390455]
#  [-6.88227273 25.63133182]
#  [-6.6521439  25.94220732]
#  [-5.99011875 26.66783125]
#  [-6.954      25.0843875 ]
#  [-7.0742     25.3738    ]
#  [-6.3596     26.8063    ]
#  [-6.63093158 26.19749474]
#  [-6.74836667 25.43923333]
#  [-6.8106     25.7823    ]
#  [-6.70722941 25.85349118]
#  [-6.8066     25.2614    ]
#  [-6.6899375  25.4980875 ]
#  [-6.2844     27.09223333]
#  [-6.49006522 26.43456957]
#  [-6.86401111 24.8822    ]
#  [-6.46696613 26.64614677]
#  [-6.38419394 26.87167879]
#  [-6.29597143 26.8376    ]
#  [-7.0335     25.8099    ]
#  [-6.61108556 26.35281556]
#  [-6.5067     26.23305   ]
#  [-6.2503     26.8748875 ]
#  [-6.68612195 26.2041561 ]]
# [[-6.00836    27.20562   ]
#  [-5.90691875 27.65629063]
#  [-5.85708837 28.10992558]
#  [-5.74601429 27.74535714]
#  [-5.89612105 27.82778289]
#  [-6.11391538 27.17562308]
#  [-5.95545495 27.38253956]
#  [-5.77326667 27.78766667]
#  [-6.14902941 27.64855588]
#  [-6.0695     28.40185   ]
#  [-6.0403     28.2256    ]
#  [ 27.95506667 -87.20833333]
#  [ 28.00972    -87.29534   ]
#  [ 28.3619     -87.541     ]
#  [ 28.2824     -87.2142    ]
#  [ 28.38217143 -87.89617143]
#  [ 28.60616667 -87.54636667]
#  [ 27.9401     -87.6398    ]
#  [ 28.1944     -87.62495   ]
#  [ 28.16015    -87.8336    ]
#  [ 27.5978     -87.7551    ]
#  [ 28.3042     -88.0435    ]
#  [ 27.4837     -87.7948    ]
#  [ 27.3774     -87.89573333]
#  [ 27.74455    -87.88555   ]]
# [[ 15.79494    -81.36204   ]
#  [ 16.19135    -81.25175   ]
#  [ 16.339325   -81.2873    ]
#  [ 16.0453     -82.013     ]
#  [ 16.303      -81.21626667]
#  [ 16.3067     -81.9541    ]
#  [ 16.2343     -81.7151    ]
#  [ 16.10096    -81.58136   ]
#  [ 15.578075   -81.388175  ]
#  [ 15.65602222 -81.08267778]
#  [ 16.31693333 -81.6127    ]
#  [ 16.3139     -81.64963333]
#  [ 15.9945     -81.4502    ]
#  [ 15.8787     -81.6397    ]
#  [ 15.30948    -81.40914   ]
#  [ 15.7963     -81.2399    ]
#  [ 15.8811     -81.545     ]
#  [ 15.6308     -81.5665    ]]
# [[ 6.5222     17.762     ]
#  [ 6.63351    17.44080167]
#  [ 6.37204792 17.60258229]
#  [ 6.55178421 17.59859079]
#  [ 6.36043182 17.46171136]
#  [ 6.78508333 17.38777778]
#  [ 7.05785455 17.58284545]
#  [ 6.91218571 16.94998571]
#  [ 6.94908    17.5367    ]
#  [ 5.9593     17.2449    ]
#  [ 6.12441596 17.40067447]
#  [ 6.70555    16.5447    ]
#  [ 6.71565    16.9073    ]
#  [ 5.937625   17.297025  ]
#  [ 6.09458    17.54851   ]
#  [ 6.2486     17.7792    ]
#  [ 6.5025     17.51875   ]
#  [ 7.29245455 17.59352727]
#  [ 6.17189231 17.7158    ]
#  [ 6.17848182 17.1304    ]
#  [ 6.51595    17.45838182]
#  [ 6.37293333 17.1969    ]
#  [ 6.6517     16.98826   ]
#  [ 6.82286667 17.11756833]
#  [ 6.15675    17.79413333]]
# [[  43.6086375  -105.150925  ]
#  [  42.11143333 -104.3294    ]
#  [  43.33962    -105.40254   ]
#  [  43.174175   -105.15045   ]
#  [  42.38239    -104.04302   ]
#  [  42.58831786 -104.09070714]
#  [  42.37431667 -104.53266667]
#  [  41.83659    -104.12451   ]
#  [  41.66103    -104.07008   ]
#  [  43.09656667 -105.3315    ]
#  [  43.35446667 -105.16312222]
#  [  43.557825   -105.59095   ]
#  [  43.80035    -104.8124    ]
#  [  41.28183333 -104.02053333]
#  [  42.04292222 -104.05398889]
#  [  43.30885    -104.34595   ]
#  [  43.88395    -104.58855   ]
#  [  43.56161111 -104.68881111]
#  [  43.39035714 -104.62248571]
#  [  42.5969     -104.2643    ]
#  [  42.92295    -104.4485    ]
#  [  42.8613     -104.5281    ]
#  [  42.58141429 -103.86761429]
#  [  43.2402     -104.7571    ]
#  [  43.1815     -104.8579    ]
#  [  43.1687     -104.6944    ]
#  [  43.18713333 -104.4663    ]]
# [[ 28.1099     -86.75805   ]
#  [ 63.0579     -24.3038    ]
#  [ 62.37539767 -24.33954651]
#  [ 62.6184     -23.5393    ]
#  [ 63.618075   -23.16825   ]
#  [ 62.41925    -23.69315   ]
#  [ 63.31265    -23.54965   ]
#  [ 62.0575     -23.8039    ]
#  [ 63.52053333 -23.36581111]
#  [ 62.89173333 -23.69783333]
#  [ 62.81711154 -23.90688077]
#  [ 63.58879091 -23.65251818]
#  [ 63.4169     -23.4203    ]
#  [ 63.5287875  -23.813875  ]
#  [ 62.58952308 -24.33616154]
#  [ 62.85392778 -24.07259444]
#  [ 62.12785    -24.12895   ]
#  [ 63.1354     -21.9266    ]
#  [ 63.2075     -21.9997    ]
#  [ 63.34217    -22.1278    ]
#  [ 63.4785     -22.441275  ]
#  [ 62.34035    -23.9122    ]
#  [ 61.75467143 -23.36967143]
#  [ 63.6635     -22.78251   ]
#  [ 62.3044     -23.6702    ]
#  [ 63.35493333 -23.3418    ]
#  [ 63.1202     -23.7698    ]
#  [ 63.1119     -23.7249    ]
#  [ 63.3985     -22.9956    ]
#  [ 61.9799     -23.65005   ]
#  [ 62.81842    -23.31044   ]
#  [ 63.43965    -22.33611   ]
#  [ 63.4632     -22.5274    ]
#  [ 63.2445     -21.9876    ]
#  [ 63.43184    -22.32516   ]
#  [ 63.550512   -22.635964  ]
#  [ 63.4251     -23.8426    ]
#  [ 63.4991     -23.2612    ]
#  [ 62.20665    -23.92265   ]
#  [ 62.304675   -24.06575   ]]
# [[23.86141364 23.63033636]
#  [23.41546154 23.4714    ]
#  [23.55111    23.55182   ]
#  [23.77330732 23.35737561]
#  [23.3606129  23.60077097]
#  [23.7111     24.2551    ]
#  [23.3151     24.2457    ]
#  [23.4907     23.7748    ]
#  [24.30903333 24.41204   ]
#  [23.5885     24.3777    ]
#  [23.78276667 24.37396667]
#  [23.83174091 24.14285   ]
#  [23.9877     24.0879    ]
#  [24.105075   23.78345   ]
#  [24.14246667 24.464     ]
#  [23.79463333 23.78293333]
#  [24.0132     24.66403333]
#  [23.6423     24.675575  ]
#  [23.8836619  24.66789048]
#  [23.4839     23.9959    ]
#  [23.189      24.3252    ]
#  [23.386895   24.15766   ]
#  [23.91336    24.09754   ]
#  [23.5028     24.13915   ]
#  [24.33012    24.39792   ]
#  [23.40535789 24.57661053]
#  [24.0088     24.3922    ]
#  [23.63577333 24.55212667]
#  [23.81002    24.57486   ]]
# [[ 1.77265238 17.90197143]
#  [ 1.57722206 17.85162206]
#  [ 1.72925    18.04455   ]
#  [ 1.361755   18.06005   ]
#  [ 1.36031356 17.89141695]
#  [ 1.38898889 17.70347778]
#  [ 1.6409625  17.3630375 ]
#  [ 1.52984444 17.19636667]
#  [ 1.15382143 18.07161786]
#  [ 1.81746842 17.39813684]
#  [ 1.08239722 17.94553889]
#  [ 0.91196145 17.82295904]
#  [ 0.9016     17.86058   ]
#  [ 1.82099545 17.63431818]
#  [ 2.9031     17.0602    ]
#  [ 2.57907    17.15027   ]
#  [ 1.6868     17.7106    ]
#  [ 1.7019     17.4394    ]
#  [ 2.31597609 16.88076087]
#  [-16.06286667  18.7881    ]]
# [[29.4989     24.4577    ]
#  [29.16721667 24.19268333]
#  [29.2012     24.2036    ]
#  [30.2523     24.0173    ]
#  [30.2614     23.9768    ]
#  [29.95656667 24.29333333]
#  [30.26618462 24.42840769]
#  [29.323015   24.18777   ]
#  [30.1252375  24.33529375]
#  [30.1464     23.97285   ]
#  [30.06690833 24.24256667]
#  [30.25       24.554425  ]
#  [29.9272     24.2557    ]
#  [29.61702222 24.22121111]
#  [29.50934    24.1654    ]
#  [29.44846667 24.1618    ]
#  [29.75685    24.2501    ]]
# [[  7.89231429 -16.031     ]
#  [  7.67773929 -16.695525  ]
#  [  7.55975909 -16.79905   ]
#  [  8.4605     -15.33746667]
#  [  8.78420469 -15.18546406]
#  [  7.87984545 -16.44539545]
#  [  8.36088605 -16.15932558]
#  [  7.42875    -16.84889   ]
#  [  8.6442801  -16.15016269]
#  [  8.78183299 -16.14136164]
#  [  8.88494233 -15.66032011]
#  [  8.35398297 -16.37601136]
#  [  8.52323571 -16.27859286]
#  [  8.32948    -16.49162   ]
#  [  8.98721905 -15.68414286]
#  [  8.77886471 -15.28821176]
#  [  7.85453759 -16.63369362]
#  [  8.88299388 -15.80761769]
#  [  8.10685714 -16.14987714]
#  [  8.11348943 -16.35519756]
#  [  8.4958     -16.0077    ]
#  [  8.30192464 -16.37798696]
#  [  8.19652857 -16.6209619 ]
#  [  7.71196    -15.86516   ]
#  [  8.42694528 -15.63929434]
#  [  8.56862576 -15.85963636]
#  [  8.99665714 -15.52232857]
#  [  8.3112226  -15.93220548]]
# [[ -4.5514     -18.2484    ]
#  [ -4.56665    -17.42345   ]
#  [ -4.54995    -18.165275  ]
#  [ -4.5897     -17.886     ]
#  [ -3.91085    -17.2263    ]
#  [ -3.99055    -17.4504    ]
#  [ -3.99263333 -17.61341111]
#  [ -4.40242903 -17.3756129 ]
#  [ -4.375784   -18.125604  ]
#  [ -4.20705    -17.1951625 ]
#  [ -3.97855    -17.8204375 ]
#  [ -4.56686    -17.61204   ]
#  [ -4.42568485 -18.34019697]
#  [ -4.24478889 -18.35741111]
#  [ -4.5664     -17.3574    ]
#  [ -4.5678     -17.8874    ]
#  [ -4.34819    -17.39607333]]
# [[ 58.5956     -27.32395714]
#  [ 58.2198     -28.0398    ]
#  [ 58.25756667 -27.66443333]
#  [ 58.34274737 -27.34537105]
#  [ 58.51533333 -28.28996667]
#  [ 58.31788148 -28.1142    ]
#  [ 58.24875    -27.61      ]
#  [ 58.208      -27.6936    ]
#  [ 58.3911     -28.2346    ]
#  [ 57.93328571 -27.62745714]
#  [ 57.9606     -27.0713    ]
#  [ 57.9636     -26.88758333]
#  [ 57.82787407 -28.13438519]
#  [ 57.93201429 -27.5663    ]
#  [ 58.0847     -27.33705312]
#  [ 57.92145714 -28.20462857]
#  [ 57.91355833 -27.387875  ]
#  [ 57.94314348 -27.86903043]
#  [ 58.61935    -28.17465   ]
#  [ 58.80905    -27.89658333]
#  [ 58.84803333 -28.03591667]
#  [ 58.91368571 -27.95265714]
#  [ 58.5796     -28.18263636]
#  [ 58.776475   -28.06515   ]
#  [ 58.3888     -28.2573    ]]
# [[84.81355    -9.2088    ]
#  [84.6952     -9.0945    ]
#  [84.87653333 -9.60416667]
#  [84.314775   -8.815725  ]
#  [84.57035    -8.8263    ]
#  [84.7965     -8.8524    ]
#  [84.4692     -9.1739    ]
#  [84.0942     -8.4713    ]
#  [84.569      -8.7297    ]
#  [85.0414     -9.4085    ]
#  [84.6894     -9.607275  ]
#  [84.5464     -8.88866667]
#  [84.62352727 -9.16024545]
#  [84.3454     -8.7326    ]
#  [84.4032     -8.7993    ]
#  [84.6673     -9.3659    ]]
# [[-16.87324     19.05863333]
#  [-17.60732222  18.43747407]
#  [-16.90954082  18.94472653]
#  [-17.3318      18.8227    ]
#  [-17.473925    19.188275  ]
#  [-17.60325     18.8594    ]
#  [-17.473       18.53488333]
#  [-17.60095     18.54543333]
#  [-17.45705937  18.43924375]
#  [-17.11917308  18.89343462]
#  [-17.60944     19.16165333]
#  [-17.1002      19.12855   ]
#  [-17.4976      19.26535   ]
#  [-17.441       19.2393    ]
#  [-17.266       18.4129    ]
#  [-17.5996      18.8347    ]]
# [[ 55.34198095 -39.79684286]
#  [ 55.28236    -39.63885   ]
#  [ 55.02246571 -40.37339143]
#  [ 55.14129583 -39.839575  ]
#  [ 54.99835    -40.51755   ]
#  [ 55.13636364 -39.58847273]
#  [ 55.00292941 -40.5235    ]
#  [ 54.92471667 -40.32025   ]
#  [ 54.96496667 -40.53426667]
#  [ 54.9939     -40.7235    ]
#  [ 54.87638    -40.03888   ]
#  [ 55.01445    -39.75515   ]
#  [ 55.01166111 -40.12368333]
#  [ 55.0311     -40.2901    ]
#  [ 54.83328333 -40.59237083]
#  [ 54.83002    -40.3581    ]
#  [ 54.68865    -40.0878    ]
#  [ 55.10445    -39.566525  ]
#  [ 54.6996     -40.3781    ]]
# [[28.2267     23.03275   ]
#  [28.41575    22.7576    ]
#  [28.78513333 23.0929    ]
#  [27.947975   23.091675  ]
#  [28.10065577 23.34085962]
#  [28.77685    22.9588    ]
#  [28.38486667 22.84706667]
#  [28.15043824 22.95667353]
#  [28.5545087  22.82793043]
#  [28.529      22.73915   ]
#  [27.058      23.2673    ]
#  [28.1239     23.2853    ]
#  [26.8903     23.54595   ]
#  [27.84335    23.16265   ]
#  [27.07426667 23.3333    ]
#  [27.64148    23.13664   ]
#  [27.132225   23.69343333]
#  [27.64935    23.4564    ]
#  [27.8517     23.4314    ]
#  [27.33196667 23.57833333]]
# [[ 2.84551364 13.89393636]
#  [ 2.4478375  13.4794    ]
#  [ 2.53001429 13.66685714]
#  [ 2.58304667 13.06855667]
#  [ 2.6812     13.3131    ]
#  [ 2.40101714 13.83426571]
#  [ 2.34215    14.06108333]
#  [ 2.43351071 13.62383036]
#  [ 1.68730556 13.2122    ]
#  [ 1.80601549 13.1937338 ]
#  [ 2.0745869  13.6014    ]
#  [ 1.7328     13.60366667]
#  [ 2.00836531 13.43772653]
#  [ 1.8471219  13.41845912]
#  [ 2.2815     13.64138   ]
#  [ 1.68091667 13.54315   ]]
